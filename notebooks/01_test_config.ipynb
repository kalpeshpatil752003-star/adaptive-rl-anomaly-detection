# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# /home/kalpe/projects/adaptive_rl_anomaly_detection

# %%
from src.config.config import config

print(config.training.device)
# Out:
# cuda

# %%
from src.config.config import config

# %%
from src.config.config import config
from src.utils.seed import set_seed

set_seed(config.training.random_seed)

print("Seed initialized successfully.")
# Out:
# Seed initialized successfully.

# %%
from src.config.config import config

print(config.paths.project_root)
print(config.paths.raw_data_dir)
# Out:
# /home/kalpe/projects/adaptive_rl_anomaly_detection/notebooks
# /home/kalpe/projects/adaptive_rl_anomaly_detection/notebooks/data/raw
