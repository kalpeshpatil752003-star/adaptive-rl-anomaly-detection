# %%
from src.models.base_model import BaseAnomalyModel

# %%
BaseAnomalyModel
# Out:
# src.models.base_model.BaseAnomalyModel

# %%
from src.models import BaseAnomalyModel

print(BaseAnomalyModel)
# Out:
# <class 'src.models.base_model.BaseAnomalyModel'>
